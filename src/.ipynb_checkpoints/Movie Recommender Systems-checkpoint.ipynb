# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
df=pd.read_csv("/home/mustafa/Learning/DataDriven/Movie Recommendation System./Datasets/movies_dataset.csv")
df
# Out:
#                         Title  \
# 0                Second more.
# 1       Data recently moment.
# 2       Help try occur start.
# 3                 Size visit.
# 4              Not bill rest.
# ..                        ...
# 995  Order environment world.
# 996                       Go.
# 997         Interesting work.
# 998           Sure end those.
# 999          Enough increase.
#
#                                            Description  \
# 0    Explain cell like itself example mother. Arriv...
# 1    Decide other recognize reason. Sort discuss on...
# 2    Want free accept maintain land among response....
# 3    First arm course lot artist so ball. Three ope...
# 4    Include such mission fire everyone garden weig...
# ..                                                 ...
# 995  Modern north at yes cold strategy six. Special...
# 996  Gas research player. Investment entire hear mu...
# 997  Something adult close couple special blue. Res...
# 998  Far purpose level public. Security wide econom...
# 999  But race home subject position wrong nothing p...
#
#                         Genres                              Keywords  \
# 0          ['Sci-Fi', 'Drama']         ['love', 'romance', 'family']
# 1    ['Adventure', 'Thriller']      ['adventure', 'love', 'mystery']
# 2       ['Drama', 'Adventure']          ['crime', 'mystery', 'love']
# 3         ['Horror', 'Sci-Fi']       ['crime', 'romance', 'mystery']
# 4         ['Comedy', 'Action']  ['mystery', 'friendship', 'romance']
# ..                         ...                                   ...
# 995     ['Thriller', 'Comedy']   ['friendship', 'romance', 'family']
# 996     ['Adventure', 'Drama']        ['love', 'adventure', 'crime']
# 997       ['Sci-Fi', 'Comedy']     ['mystery', 'adventure', 'crime']
# 998        ['Drama', 'Action']       ['friendship', 'crime', 'love']
# 999        ['Drama', 'Action']     ['crime', 'adventure', 'romance']
#
#                                                   Cast               Director  \
# 0    ['William Martin', 'Ruth Jones', 'Emily Wells'...         Steven Russell
# 1    ['Alexis Nguyen', 'Anna Garcia', 'Amy Parker',...  Elizabeth Sherman DDS
# 2    ['Joyce Brady', 'Scott Wise', 'Brian Thompson'...       Olivia Contreras
# 3    ['Thomas Fowler', 'Henry Flores', 'Megan Moore...          Michael Allen
# 4    ['Tiffany Alvarez', 'Janet Valdez', 'Frank Rod...           David Taylor
# ..                                                 ...                    ...
# 995  ['Alice Mann', 'Clayton Contreras', 'Joseph Br...             Jacob Wood
# 996  ['Wyatt Heath', 'Michelle Zhang', 'Andrea Mill...          Timothy Weber
# 997  ['Stephanie Scott MD', 'Erin Shaw', 'Amber Cla...          Lauren Warren
# 998  ['Debbie Smith', 'Michelle Fowler', 'Tina Chri...          Michelle Cruz
# 999  ['Justin Mckee', 'Bryan Spears', 'Angela Snyder']            Mary Powers
#
#     Release_Date  Ratings  Popularity    Budget    Revenue  Runtime
# 0     2014-04-05      4.8          53  27142100  334579029      102
# 1     2020-09-20      2.8          46  27033909  148014540       95
# 2     2023-01-06      4.0          53   7259955  320808172      115
# 3     2020-09-14      1.9          30  13748580  253192487      122
# 4     2017-06-25      8.4          10  85573059   19552767      110
# ..           ...      ...         ...       ...        ...      ...
# 995   2021-05-14      8.7          23  11221217  477286214      173
# 996   2014-10-08      2.8          58  63671027  169473769      141
# 997   2014-08-19      4.4          15  58937707  378415533       67
# 998   2016-06-18      9.0          10  71032233  259462556      155
# 999   2019-06-19      9.8           8  45723406  236750719      172
#
# [1000 rows x 12 columns]

# %%
# Preprocessing: Combine relevant text columns into a single feature
df['combined_features'] = df['Genres'] + ' ' + df['Keywords'] + ' ' + df['Cast'] + ' ' + df['Director']

# Initialize TF-IDF Vectorizer
tfidf = TfidfVectorizer(stop_words='english')

# Fit and transform the data
tfidf_matrix = tfidf.fit_transform(df['combined_features'])

# Compute similarity matrix
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
def recommend_movies(title, cosine_sim=cosine_sim):
    # Get the index of the movie that matches the title
    idx = df[df['Title'] == title].index[0]

    # Get the pairwise similarity scores of all movies with that movie
    sim_scores = list(enumerate(cosine_sim[idx]))

    # Sort the movies based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the scores of the 10 most similar movies
    sim_scores = sim_scores[1:11]

    # Get the movie indices
    movie_indices = [i[0] for i in sim_scores]

    # Return the top 10 most similar movies
    return df[['Title', 'Ratings']].iloc[movie_indices]

# %%
recommend_movies('Second more.')
# Out:
#                            Title  Ratings
# 613                     Our arm.      2.8
# 24                     Far know.      9.0
# 901           Job line security.      3.4
# 413              Determine fund.      5.5
# 949  Charge necessary certainly.      3.1
# 938       In direction magazine.      3.1
# 201           Good tell capital.      6.2
# 496                  Factor get.      4.2
# 890   Social rule month culture.      9.8
# 667              Outside father.      4.2

# %%
recommended_movies=recommend_movies('Enough increase.')
plt.figure(figsize=(10, 6))
plt.barh(recommended_movies['Title'], recommended_movies['Ratings'], color='pink')
plt.xlabel('Ratings')
plt.title('Recommended Movies')
plt.gca().invert_yaxis()  # Invert y-axis to display the highest rating on top
plt.show()

# %%
recommended_movies=recommend_movies('Help try occur start.')

plt.figure(figsize=(10, 6))
plt.barh(recommended_movies['Title'], recommended_movies['Ratings'], color='skyblue')
plt.xlabel('Ratings')
plt.title('Recommended Movies')
plt.gca().invert_yaxis()  # Invert y-axis to display the highest rating on top
plt.show()

# %%
recommended_movies=recommend_movies('Order environment world.')

plt.figure(figsize=(10, 6))
plt.barh(recommended_movies['Title'], recommended_movies['Ratings'], color='skyblue')
plt.xlabel('Ratings')
plt.title('Recommended Movies')
plt.gca().invert_yaxis()  # Invert y-axis to display the highest rating on top
plt.show()

# %%
recommended_movies = recommend_movies('Second more.')

plt.figure(figsize=(10, 6))
plt.barh(recommended_movies['Title'], recommended_movies['Ratings'], color='red')
plt.xlabel('Ratings')
plt.title('Recommended Movies')
plt.gca().invert_yaxis()  # Invert y-axis to display the highest rating on top
plt.show()

# %%
recommended_movies=recommend_movies('Interesting work.')
plt.figure(figsize=(10, 6))
plt.scatter(recommended_movies['Title'], recommended_movies['Ratings'], color='green', marker='o')
plt.xlabel('Movie Title')
plt.ylabel('Ratings')
plt.title('Recommended Movies')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
recommended_movies=recommend_movies('Interesting work.')
recommended_movies
# Out:
#                            Title  Ratings
# 443              Unit available.      7.6
# 64        Cup article drive add.      7.1
# 899       Along yourself player.      2.1
# 40   Question personal increase.      1.9
# 585           Than bed over cut.      6.3
# 695               Anything good.      4.6
# 972                  Stage name.      3.8
# 608         Hand nothing rather.      7.3
# 701   Particular president huge.      8.9
# 870               Wind audience.      2.4

# %%
def recommend_movies(title, cosine_sim=cosine_sim):
    # Get the index of the movie that matches the title
    idx = df[df['Title'] == title].index[0]

    # Get the pairwise similarity scores of all movies with that movie
    sim_scores = list(enumerate(cosine_sim[idx]))

    # Sort the movies based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the scores of the 10 most similar movies
    sim_scores = sim_scores[1:11]

    # Get the movie indices
    movie_indices = [i[0] for i in sim_scores]

    # Return the top 10 most similar movies
    return df[['Title', 'Ratings']].iloc[movie_indices]

recommend_movies('Second more.')
# Out:
#                            Title  Ratings
# 613                     Our arm.      2.8
# 24                     Far know.      9.0
# 901           Job line security.      3.4
# 413              Determine fund.      5.5
# 949  Charge necessary certainly.      3.1
# 938       In direction magazine.      3.1
# 201           Good tell capital.      6.2
# 496                  Factor get.      4.2
# 890   Social rule month culture.      9.8
# 667              Outside father.      4.2

# %%
recommend_movies('Second more.')
# Out:
#                            Title  Ratings
# 613                     Our arm.      2.8
# 24                     Far know.      9.0
# 901           Job line security.      3.4
# 413              Determine fund.      5.5
# 949  Charge necessary certainly.      3.1
# 938       In direction magazine.      3.1
# 201           Good tell capital.      6.2
# 496                  Factor get.      4.2
# 890   Social rule month culture.      9.8
# 667              Outside father.      4.2

# %%
import gradio as gr

# Define your recommend_movies function here

def recommend_movies(title, cosine_sim=cosine_sim):
    try:    # Get the index of the movie that matches the title
        idx = df[df['Title'] == title].index[0]

        # Get the pairwise similarity scores of all movies with that movie
        sim_scores = list(enumerate(cosine_sim[idx]))

        # Sort the movies based on the similarity scores
        sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

        # Get the scores of the 10 most similar movies
        sim_scores = sim_scores[1:11]

        # Get the movie indices
        movie_indices = [i[0] for i in sim_scores]

        # Return the top 10 most similar movies as a formatted string
        return df[['Title', 'Ratings']].iloc[movie_indices](index=False)
    except IndexError:
        return "Error: Movie title not found."
    except Exception as e:
        return f"An unexpected error occurred: {e}"

# Define Gradio interface
input_text = gr.Textbox(label="Enter a movie title")
output_text = gr.Textbox(label="Recommended Movies")

gr.Interface(recommend_movies, inputs=input_text, outputs=output_text, title="Movie Recommendation System").launch()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [154], in <cell line: 32>()
#      29 input_text = gr.Textbox(label="Enter a movie title")
#      30 output_text = gr.Textbox(label="Recommended Movies")
# ---> 32 gr.Interface(recommend_movies, inputs=input_text, outputs=output_text, title="Movie Recommendation System").launch()
#
# File ~/anaconda3/lib/python3.9/site-packages/gradio/interface.py:509, in Interface.__init__(self, fn, inputs, outputs, examples, cache_examples, examples_per_page, live, title, description, article, thumbnail, theme, css, allow_flagging, flagging_options, flagging_dir, flagging_callback, analytics_enabled, batch, max_batch_size, api_name, _api_mode, allow_duplication, concurrency_limit, js, head, additional_inputs, additional_inputs_accordion, submit_btn, stop_btn, clear_btn, delete_cache, **kwargs)
#     506 if _clear_btn is None:
#     507     raise RenderError("Clear button not rendered")
# --> 509 self.attach_submit_events(_submit_btn, _stop_btn)
#     510 self.attach_clear_events(_clear_btn, input_component_column)
#     511 if duplicate_btn is not None:
#
# File ~/anaconda3/lib/python3.9/site-packages/gradio/interface.py:743, in Interface.attach_submit_events(self, _submit_btn, _stop_btn)
#     734     _stop_btn.click(
#     735         cleanup,
#     736         inputs=None,
#    (...)
#     740         show_api=False,
#     741     )
#     742 else:
# --> 743     on(
#     744         triggers,
#     745         fn,
#     746         self.input_components,
#     747         self.output_components,
#     748         api_name=self.api_name,
#     749         scroll_to_output=True,
#     750         preprocess=not (self.api_mode),
#     751         postprocess=not (self.api_mode),
#     752         batch=self.batch,
#     753         max_batch_size=self.max_batch_size,
#     754         concurrency_limit=self.concurrency_limit,
#     755     )
#
# File ~/anaconda3/lib/python3.9/site-packages/gradio/events.py:424, in on(triggers, fn, inputs, outputs, api_name, scroll_to_output, show_progress, queue, batch, max_batch_size, preprocess, postprocess, cancels, every, js, concurrency_limit, concurrency_id, show_api)
#     419 else:
#     420     triggers = [
#     421         EventListenerMethod(t.__self__ if t.has_trigger else None, t.event_name)
#     422         for t in triggers
#     423     ]  # type: ignore
# --> 424 dep, dep_index = Context.root_block.set_event_trigger(
#     425     triggers,
#     426     fn,
#     427     inputs,
#     428     outputs,
#     429     preprocess=preprocess,
#     430     postprocess=postprocess,
#     431     scroll_to_output=scroll_to_output,
#     432     show_progress=show_progress,
#     433     api_name=api_name,
#     434     js=js,
#     435     concurrency_limit=concurrency_limit,
#     436     concurrency_id=concurrency_id,
#     437     queue=queue,
#     438     batch=batch,
#     439     max_batch_size=max_batch_size,
#     440     every=every,
#     441     show_api=show_api,
#     442 )
#     443 set_cancel_events(triggers, cancels)
#     444 return Dependency(None, dep, dep_index, fn)
#
# File ~/anaconda3/lib/python3.9/site-packages/gradio/blocks.py:911, in Blocks.set_event_trigger(self, targets, fn, inputs, outputs, preprocess, postprocess, scroll_to_output, show_progress, api_name, js, no_target, queue, batch, max_batch_size, cancels, every, collects_event_data, trigger_after, trigger_only_on_success, trigger_mode, concurrency_limit, concurrency_id, show_api)
#     908     outputs = [outputs]
#     910 if fn is not None and not cancels:
# --> 911     check_function_inputs_match(fn, inputs, inputs_as_dict)
#     912 if every is not None and every <= 0:
#     913     raise ValueError("Parameter every must be positive or None")
#
# File ~/anaconda3/lib/python3.9/site-packages/gradio/utils.py:846, in check_function_inputs_match(fn, inputs, inputs_as_dict)
#     844 if param.kind in [param.POSITIONAL_ONLY, param.POSITIONAL_OR_KEYWORD]:
#     845     if not is_special_typed_parameter(name, parameter_types):
# --> 846         if not has_default:
#     847             min_args += 1
#     848         max_args += 1
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
